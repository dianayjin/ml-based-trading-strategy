# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, LSTM, Reshape
from tensorflow.keras.regularizers import l2

# load data
scaled_data = pd.read_csv(os.path.join('..', 'data', 'processed', 'scaled_data.csv'), index_col= ['Date'])

display(scaled_data)

def create_lagged_dataset(data, lag):
    X, y = [], []
    for i in range(len(data) - lag):
        X.append(data.iloc[i:(i + lag)].values)
        y.append(data.iloc[i + lag]['_MKT'])
    return np.array(X), np.array(y)

# lagged dataset
lag = 4 # use prev 4 week data to predict (approx. 1 month)
X, y = create_lagged_dataset(scaled_data, lag=lag)

# time-based split (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f'Training data shape: {X_train.shape}')
print(f'Testing data shape: {X_test.shape}')

# input shape
input_shape = (X.shape[1], X.shape[2])
# Out:
#                   PE        M2       CPI      _MKT
# Date
# 1988-04-10  0.095785  0.303164  0.629228  0.001175
# 1988-04-17  0.076628  0.309296  0.611069  0.000463
# 1988-04-24  0.076628  0.309296  0.611069  0.000465
# 1988-05-01  0.080460  0.309296  0.611069  0.000606
# 1988-05-08  0.072797  0.309296  0.611069  0.000296
# ...              ...       ...       ...       ...
# 2024-04-07  0.620690  0.134544  0.534995  0.990466
# 2024-04-14  0.605364  0.158827  0.455907  0.974132
# 2024-04-21  0.578544  0.158827  0.455907  0.943699
# 2024-04-28  0.605364  0.158827  0.455907  0.970449
# 2024-05-05  0.597701  0.158827  0.455907  0.976569
#
# [1883 rows x 4 columns]
# Training data shape: (1503, 4, 4)
# Testing data shape: (376, 4, 4)

# %%
# build
inputs = Input(shape=input_shape)
x = Conv1D(filters=16, kernel_size=2, activation='relu')(inputs)
x = Conv1D(filters=32, kernel_size=2, activation='relu')(x)
x = Conv1D(filters=64, kernel_size=2, activation='relu')(x)
x = Flatten()(x)
x = Dense(32, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(16, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dense(8, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Reshape((8, 1))(x)
x = LSTM(50, return_sequences=True)(x)
x = LSTM(50)(x)
outputs = Dense(1)(x)

# compile
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mse')

# output summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 4)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 3, 16)          │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 2, 32)          │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 1, 64)          │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 8, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 8, 50)          │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,755 (151.39 KB)
#  Trainable params: 38,755 (151.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train
history = model.fit(X_train, y_train, epochs=150, validation_data=(X_test, y_test), verbose=0)

# %%
# predict
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# evaluate model
is_mse = mean_squared_error(y_train, train_predictions)
is_rmse = np.sqrt(is_mse)
is_mae = mean_absolute_error(y_train, train_predictions)
is_mape = mean_absolute_percentage_error(y_train, train_predictions)
is_r2 = r2_score(y_train, train_predictions)
os_mse = mean_squared_error(y_test, test_predictions)
os_rmse = np.sqrt(os_mse)
os_mae = mean_absolute_error(y_test, test_predictions)
os_mape = mean_absolute_percentage_error(y_test, test_predictions)
os_r2 = r2_score(y_test, test_predictions)

print(f'In-Sample MSE: {is_mse}')
print(f'Out-of-Sample MSE: {os_mse}')
print(f'In-Sample RMSE: {is_rmse}')
print(f'Out-of-Sample RMSE: {os_rmse}')
print(f'In-Sample MAE: {is_mae}')
print(f'Out-of-Sample MAE: {os_mae}')
print(f'In-Sample MAPE: {is_mape}')
print(f'Out-of-Sample MAPE: {os_mape}')
print(f'In-Sample R2: {is_r2}')
print(f'Out-of-Sample R2: {os_r2}')
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# In-Sample MSE: 5.134622650931225e-05
# Out-of-Sample MSE: 0.003399793384968447
# In-Sample RMSE: 0.007165628130827907
# Out-of-Sample RMSE: 0.05830774721225685
# In-Sample MAE: 0.006045509020832316
# Out-of-Sample MAE: 0.048412524229580645
# In-Sample MAPE: 3100168314.772268
# Out-of-Sample MAPE: 0.0718003644662732
# In-Sample R2: 0.9947335205764829
# Out-of-Sample R2: 0.8774154991788479

# %%
# training & validation loss values as fxn of epochs
plt.figure(figsize=(5, 3))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
# actual vs predicted values
plt.figure(figsize=(5, 3))
plt.plot(y_test, label='Actual')
plt.plot(test_predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('Stock Index Value')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit

# k-fold
tscv = TimeSeriesSplit(n_splits=5)
cross_val_results = []

for train_index, test_index in tscv.split(X):
    X_train_cv, X_test_cv = X[train_index], X[test_index]
    y_train_cv, y_test_cv = y[train_index], y[test_index]

    # train
    model.fit(X_train_cv, y_train_cv, epochs=150, validation_data=(X_test_cv, y_test_cv))

    # predict
    test_predictions_cv = model.predict(X_test_cv)
    
    # evaluate
    mse_cv = mean_squared_error(y_test_cv, test_predictions_cv)
    rmse_cv = np.sqrt(mse_cv)
    mae_cv = mean_absolute_error(y_test_cv, test_predictions_cv)
    mape_cv = mean_absolute_percentage_error(y_test_cv, test_predictions_cv)
    r2_cv = r2_score(y_test_cv, test_predictions_cv)
    
    cross_val_results.append((mse_cv, rmse_cv, mae_cv, mape_cv, r2_cv))

# avg metrics
avg_cross_val_results = np.mean(cross_val_results, axis=0)
print(f'Cross-Validation MSE: {avg_cross_val_results[0]}')
print(f'Cross-Validation RMSE: {avg_cross_val_results[1]}')
print(f'Cross-Validation MAE: {avg_cross_val_results[2]}')
print(f'Cross-Validation MAPE: {avg_cross_val_results[3]}')
print(f'Cross-Validation R2: {avg_cross_val_results[4]}')
# Out:
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4493e-04 - val_loss: 1.4809e-04
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3326e-04 - val_loss: 1.4101e-04
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2723e-04 - val_loss: 1.8078e-04
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2357e-04 - val_loss: 2.1189e-04
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1784e-04 - val_loss: 2.4172e-04
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1631e-04 - val_loss: 3.9664e-04
# Epoch 7/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1194e-04 - val_loss: 5.0131e-04
# Epoch 8/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1045e-04 - val_loss: 4.9272e-04
# Epoch 9/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0838e-04 - val_loss: 5.1363e-04
# Epoch 10/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0786e-04 - val_loss: 5.4253e-04
# Epoch 11/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0632e-04 - val_loss: 7.0437e-04
# Epoch 12/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9693e-05 - val_loss: 9.1343e-04
# Epoch 13/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4798e-05 - val_loss: 0.0011
# Epoch 14/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2539e-05 - val_loss: 9.7905e-04
# Epoch 15/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.9694e-05 - val_loss: 0.0010
# Epoch 16/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.3052e-05 - val_loss: 0.0011
# Epoch 17/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7667e-05 - val_loss: 0.0013
# Epoch 18/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.
150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0502e-04 - val_loss: 0.0044
# Epoch 19/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1334e-04 - val_loss: 0.0078
# Epoch 20/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4331e-04 - val_loss: 0.0072
# Epoch 21/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5330e-05 - val_loss: 0.0072
# Epoch 22/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0282e-04 - val_loss: 0.0065
# Epoch 23/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2168e-05 - val_loss: 0.0043
# Epoch 24/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0515e-04 - val_loss: 0.0081
# Epoch 25/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9859e-05 - val_loss: 0.0069
# Epoch 26/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6141e-05 - val_loss: 0.0068
# Epoch 27/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0676e-05 - val_loss: 0.0046
# Epoch 28/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3869e-05 - val_loss: 0.0057
# Epoch 29/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2700e-04 - val_loss: 0.0084
# Epoch 30/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0380e-04 - val_loss: 0.0054
# Epoch 31/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1975e-05 - val_loss: 0.0037
# Epoch 32/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3536e-04 - val_loss: 0.0064
# Epoch 33/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1889e-04 - val_loss: 0.0048
# Epoch 34/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4274e-05 - val_loss: 0.0060
# Epoch 35/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7659e-05 - val_loss: 0.0077
# Epoch 36/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3373e-04 - val_loss: 0.0055
# Epoch 37/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1328e-05 - val_loss: 0.0057
# Epoch 38/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5939e-05 - val_loss: 0.0062
# Epoch 39/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7601e-05 - val_loss: 0.0048
# Epoch 40/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4861e-05 - val_loss: 0.0042
# Epoch 41/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4840e-05 - val_loss: 0.0056
# Epoch 42/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2193e-05 - val_loss: 0.0065
# Epoch 43/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3268e-04 - val_loss: 0.0061
# Epoch 44/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2588e-04 - val_loss: 0.0087
# Epoch 45/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0395e-04 - val_loss: 0.0045
# Epoch 46/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4000e-05 - val_loss: 0.0052
# Epoch 47/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9026e-05 - val_loss: 0.0074
# Epoch 48/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1101e-04 - val_loss: 0.0066
# Epoch 49/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0996e-04 - val_loss: 0.0061
# Epoch 50/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8994e-05 - val_loss: 0.0072
# Epoch 51/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2513e-04 - val_loss: 0.0069
# Epoch 52/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1991e-05 - val_loss: 0.0058
# Epoch 53/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3377e-05 - val_loss: 0.0041
# Epoch 54/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3397e-04 - val_loss: 0.0055
# Epoch 55/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2319e-05 - val_loss: 0.0051
# Epoch 56/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3291e-05 - val_loss: 0.0058
# Epoch 57/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3083e-05 - val_loss: 0.0056
# Epoch 58/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1525e-04 - val_loss: 0.0056
# Epoch 59/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2433e-05 - val_loss: 0.0055
# Epoch 60/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0707e-04 - val_loss: 0.0054
# Epoch 61/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5672e-05 - val_loss: 0.0071
# Epoch 62/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4320e-04 - val_loss: 0.0059
# Epoch 63/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9037e-05 - val_loss: 0.0076
# Epoch 64/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1174e-04 - val_loss: 0.0032
# Epoch 65/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2621e-04 - val_loss: 0.0059
# Epoch 66/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6827e-05 - val_loss: 0.0056
# ...
# Epoch 128/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2402e-04 - val_loss: 0.0081
# Epoch 129/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4706e-05 - val_loss: 0.0062
# Epoch 130/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4725e-05 - val_loss: 0.0059
# Epoch 131/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4190e-05 - val_loss: 0.0033
# Epoch 132/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.3695e-05 - val_loss: 0.0058
# Epoch 133/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0240e-04 - val_loss: 0.0068
# Epoch 134/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0334e-04 - val_loss: 0.0051
# Epoch 135/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8694e-05 - val_loss: 0.0043
# Epoch 136/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8039e-05 - val_loss: 0.0058
# Epoch 137/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7634e-05 - val_loss: 0.0058
# Epoch 138/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7997e-05 - val_loss: 0.0050
# Epoch 139/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4149e-05 - val_loss: 0.0052
# Epoch 140/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0015e-05 - val_loss: 0.0055
# Epoch 141/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3148e-05 - val_loss: 0.0061
# Epoch 142/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6350e-05 - val_loss: 0.0056
# Epoch 143/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0686e-04 - val_loss: 0.0080
# Epoch 144/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9965e-05 - val_loss: 0.0052
# Epoch 145/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8171e-05 - val_loss: 0.0063
# Epoch 146/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2789e-05 - val_loss: 0.0056
# Epoch 147/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1284e-05 - val_loss: 0.0059
# Epoch 148/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0284e-04 - val_loss: 0.0053
# Epoch 149/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2884e-05 - val_loss: 0.0061
# Epoch 150/150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4312e-05 - val_loss: 0.0053
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5021e-04 - val_loss: 0.0387
# Epoch 2/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2073e-04 - val_loss: 0.0267
# Epoch 3/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4745e-04 - val_loss: 0.0203
# Epoch 4/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2846e-04 - val_loss: 0.0134
# Epoch 5/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5297e-04 - val_loss: 0.0101
# Epoch 6/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1593e-04 - val_loss: 0.0072
# Epoch 7/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0258e-04 - val_loss: 0.0083
# Epoch 8/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0415e-04 - val_loss: 0.0078
# Epoch 9/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1234e-04 - val_loss: 0.0058
# Epoch 10/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1157e-04 - val_loss: 0.0072
# Epoch 11/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6600e-05 - val_loss: 0.0074
# Epoch 12/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.7848e-05 - val_loss: 0.0082
# Epoch 13/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0539e-04 - val_loss: 0.0057
# Epoch 14/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6235e-05 - val_loss: 0.0048
# Epoch 15/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0093e-04 - val_loss: 0.0042
# Epoch 16/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7005e-05 - val_loss: 0.0038
# Epoch 17/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0354e-04 - val_loss: 0.0039
# Epoch 18/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6983e-05 - val_loss: 0.0047
# Epoch 19/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0136e-04 - val_loss: 0.0215
# Epoch 20/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5845e-04 - val_loss: 0.0125
# Epoch 21/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0980e-04 - val_loss: 0.0070
# Epoch 22/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7594e-04 - val_loss: 0.0113
# Epoch 23/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1235e-04 - val_loss: 0.0081
# Epoch 24/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1622e-04 - val_loss: 0.0069
# Epoch 25/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2406e-05 - val_loss: 0.0044
# Epoch 26/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2478e-04 - val_loss: 0.0088
# Epoch 27/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7322e-05 - val_loss: 0.0063
# Epoch 28/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9123e-05 - val_loss: 0.0065
# Epoch 29/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2869e-04 - val_loss: 0.0076
# Epoch 30/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4705e-04 - val_loss: 0.0079
# Epoch 31/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6632e-05 - val_loss: 0.0066
# Epoch 32/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6158e-05 - val_loss: 0.0063
# Epoch 33/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5131e-05 - val_loss: 0.0057
# Epoch 34/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2782e-04 - val_loss: 0.0075
# Epoch 35/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5405e-04 - val_loss: 0.0148
# Epoch 36/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2923e-04 - val_loss: 0.0087
# Epoch 37/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1509e-04 - val_loss: 0.0070
# Epoch 38/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3002e-05 - val_loss: 0.0058
# Epoch 39/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7533e-05 - val_loss: 0.0060
# Epoch 40/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6090e-05 - val_loss: 0.0056
# Epoch 41/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6861e-05 - val_loss: 0.0071
# Epoch 42/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.
150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7281e-05 - val_loss: 0.0095
# Epoch 99/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4048e-05 - val_loss: 0.0064
# Epoch 100/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4913e-04 - val_loss: 0.0152
# Epoch 101/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3689e-04 - val_loss: 0.0098
# Epoch 102/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1976e-04 - val_loss: 0.0093
# Epoch 103/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8557e-05 - val_loss: 0.0111
# Epoch 104/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6629e-05 - val_loss: 0.0084
# Epoch 105/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3825e-04 - val_loss: 0.0133
# Epoch 106/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6888e-04 - val_loss: 0.0149
# Epoch 107/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9076e-05 - val_loss: 0.0091
# Epoch 108/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0339e-04 - val_loss: 0.0101
# Epoch 109/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6477e-05 - val_loss: 0.0112
# Epoch 110/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9389e-05 - val_loss: 0.0092
# Epoch 111/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0742e-05 - val_loss: 0.0094
# Epoch 112/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8163e-05 - val_loss: 0.0079
# Epoch 113/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0828e-04 - val_loss: 0.0171
# Epoch 114/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5660e-04 - val_loss: 0.0158
# Epoch 115/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3425e-05 - val_loss: 0.0120
# Epoch 116/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9547e-05 - val_loss: 0.0097
# Epoch 117/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0496e-04 - val_loss: 0.0135
# Epoch 118/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9084e-05 - val_loss: 0.0129
# Epoch 119/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3528e-05 - val_loss: 0.0117
# Epoch 120/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4080e-05 - val_loss: 0.0097
# Epoch 121/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0218e-04 - val_loss: 0.0087
# Epoch 122/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9559e-05 - val_loss: 0.0088
# Epoch 123/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0646e-04 - val_loss: 0.0090
# Epoch 124/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1035e-04 - val_loss: 0.0124
# Epoch 125/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2787e-05 - val_loss: 0.0085
# Epoch 126/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1523e-05 - val_loss: 0.0119
# Epoch 127/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6310e-04 - val_loss: 0.0203
# Epoch 128/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0951e-04 - val_loss: 0.0144
# Epoch 129/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7578e-05 - val_loss: 0.0119
# Epoch 130/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7728e-05 - val_loss: 0.0110
# Epoch 131/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3016e-05 - val_loss: 0.0103
# Epoch 132/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2538e-04 - val_loss: 0.0134
# Epoch 133/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5731e-04 - val_loss: 0.0176
# Epoch 134/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3236e-04 - val_loss: 0.0160
# Epoch 135/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0148e-04 - val_loss: 0.0104
# Epoch 136/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.0810e-05 - val_loss: 0.0114
# Epoch 137/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0898e-05 - val_loss: 0.0079
# Epoch 138/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9634e-05 - val_loss: 0.0112
# Epoch 139/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0526e-04 - val_loss: 0.0097
# Epoch 140/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0915e-04 - val_loss: 0.0090
# Epoch 141/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1859e-05 - val_loss: 0.0091
# Epoch 142/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3484e-04 - val_loss: 0.0107
# Epoch 143/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0728e-05 - val_loss: 0.0098
# Epoch 144/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4479e-05 - val_loss: 0.0098
# Epoch 145/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6938e-05 - val_loss: 0.0099
# Epoch 146/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9865e-05 - val_loss: 0.0075
# Epoch 147/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0959e-05 - val_loss: 0.0066
# Epoch 148/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7716e-05 - val_loss: 0.0074
# Epoch 149/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2718e-05 - val_loss: 0.0077
# Epoch 150/150
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0525e-04 - val_loss: 0.0101
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Cross-Validation MSE: 0.003992303252314734
# Cross-Validation RMSE: 0.05478086454409481
# Cross-Validation MAE: 0.045386994680466974
# Cross-Validation MAPE: 0.21615167596614665
# Cross-Validation R2: -0.06334848165373339

# %% [markdown]
# ## Testing the Model
#
# We test and validate our hypthesis by implementing a simple trading strategy that buys the underlying, provided a positive outlook, and sells the underlying otherwise, benchmarking it with a buy and hold strategy of the underlying.

# %%
# load raw market data
data = pd.read_excel(os.path.join('..', 'data', 'raw', 'market_data.xlsx'), usecols=['Date', 'PE', 'CPI', 'M2', '_MKT'])
data.set_index(['Date'], inplace=True)

# generate buy/sell signals
def generate_signals(predictions):
    signals = np.zeros_like(predictions)
    signals[1:] = np.where(predictions[1:] > predictions[:-1], 1, -1)  # buy if next prediction is higher, sell if lower
    return signals

train_signals = generate_signals(train_predictions.flatten())
test_signals = generate_signals(test_predictions.flatten())

train_signals = train_signals[1:]
test_signals = test_signals[1:]

# returns
def calculate_pnl(signals, returns):
    return signals * returns  # PnL

# market returns
market_returns_train = data['_MKT'].iloc[:train_size].pct_change().dropna().values
market_returns_test = data['_MKT'].iloc[train_size+lag:].pct_change().dropna().values

train_pnl = calculate_pnl(train_signals, market_returns_train)
test_pnl = calculate_pnl(test_signals, market_returns_test)

# cumulative returns
train_cumulative_pnl = np.cumsum(train_pnl[1:])
test_cumulative_pnl = np.cumsum(test_pnl[1:])

# IR
def calculate_ir(pnl, market_returns):
    excess_returns = pnl - market_returns[:len(pnl)]
    return (np.mean(excess_returns) / np.std(excess_returns)) * np.sqrt(52)  # Annualized IR

train_ir = calculate_ir(train_pnl[1:], market_returns_train[1:])
test_ir = calculate_ir(test_pnl[1:], market_returns_test[1:])

print(f'In-Sample IR: {train_ir}')
print(f'Out-of-Sample IR: {test_ir}')

# underlying strategy returns
def calculate_buy_and_hold_returns(data, train_size, lag):
    bh_returns_train = data['_MKT'].iloc[:train_size].pct_change().dropna().values
    bh_returns_test = data['_MKT'].iloc[train_size+lag:].pct_change().dropna().values
    
    bh_cumulative_returns_train = np.cumsum(bh_returns_train)
    bh_cumulative_returns_test = np.cumsum(bh_returns_test)
    
    return bh_cumulative_returns_train, bh_cumulative_returns_test

bh_cumulative_returns_train, bh_cumulative_returns_test = calculate_buy_and_hold_returns(data, train_size, lag)
# Out:
# In-Sample IR: 0.43431420212389693
# Out-of-Sample IR: -0.5790033646488644

# %%
# plot
plt.figure(figsize=(14, 7))
plt.plot(data.index[:train_size][1:len(train_cumulative_pnl)+1], train_cumulative_pnl, label='In-Sample Cumulative PnL')
plt.plot(data.index[:train_size][1:len(bh_cumulative_returns_train)+1], bh_cumulative_returns_train, label='Buy and Hold In-Sample', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Cumulative PnL')
plt.title('Cumulative Returns of the Trading Strategy vs Buy and Hold')
plt.legend()
plt.show()

# %%
# plot
plt.figure(figsize=(14, 7))
plt.plot(data.index[train_size+lag:][1:len(test_cumulative_pnl)+1], test_cumulative_pnl, label='Out-of-Sample Cumulative PnL')
plt.plot(data.index[train_size+lag:][1:len(bh_cumulative_returns_test)+1], bh_cumulative_returns_test, label='Buy and Hold Out-of-Sample', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Cumulative PnL')
plt.title('Cumulative Returns of the Trading Strategy vs Buy and Hold')
plt.legend()
plt.show()
